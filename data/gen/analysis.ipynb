# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("generatorv9.csv")
# Out:
# The kernel failed to start due to the missing module 'psutil'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.

# %%
df.head()
# Out:
#       disc_loss  gen_loss  val_loss
# 0  9.816300e+00   -0.0377   -0.0408
# 1  9.526900e+00   -0.0359   -0.0393
# 2  9.055600e+00   -0.0344   -0.0387
# 3  2.927979e+31   -0.0337   -0.0399
# 4  7.405900e+00   -0.0360   -0.0463

# %%
import matplotlib
matplotlib.get_cachedir()
# Out:
# '/home/vish/.cache/matplotlib'

# %%
x = range(1, 20)
plt.plot(x, df['disc_loss'], label="Discriminator Loss")
plt.plot(x, df['gen_loss'], label="Generator Loss")
plt.plot(x, df['val_loss'], label="Validation Loss")
plt.plot(x, np.zeros(59), linestyle="dashed", label="Desired Value")
leg = plt.legend(loc="lower right")

plt.title("cGAN Loss Over 60 Epochs")
plt.xlabel("Epoch #")
plt.ylabel("Loss (Wasserstein Distance)")
sns.set_theme()

plt.show('darkgrid')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       3 plt.plot(x, df['gen_loss'], label="Generator Loss")
#       4 plt.plot(x, df['val_loss'], label="Validation Loss")
# ----> 5 plt.plot(x, np.zeros(59), linestyle="dashed", label="Desired Value")
#       6 leg = plt.legend(loc="lower right")
#       8 plt.title("cGAN Loss Over 60 Epochs")
#
# File ~/projects/research-project/data/venv/lib/python3.8/site-packages/matplotlib/pyplot.py:2740, in plot(scalex, scaley, data, *args, **kwargs)
#    2738 @_copy_docstring_and_deprecators(Axes.plot)
#    2739 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2740     return gca().plot(
#    2741         *args, scalex=scalex, scaley=scaley,
#    2742         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
df = pd.read_csv("generatorv8.csv")
x = range(1, 60)
#plt.plot(x, df['disc_loss'], label="Discriminator Loss")
plt.plot(x, df['wass_dist'], label="Wasserstein Distance")
plt.plot(x, df['gen_loss'], label="Generator Loss")
plt.plot(x, df['val_loss'], label="Validation Loss")
plt.plot(x, np.zeros(59), linestyle="dashed", label="Desired Value")
leg = plt.legend(loc="lower right", bbox_to_anchor=(1.04, 1.04))

plt.title("cGAN Loss Over 60 Epochs")
plt.xlabel("Epoch #")
plt.ylabel("Loss (Wasserstein Distance)")
sns.set_theme()

plt.show('darkgrid')

# %%
dreal = pd.read_csv("./genv9/dreal_proc.txt", sep=',')
dfake = pd.read_csv("./genv9/dfake_proc.txt", sep=',')
dreal.head()
# Out:
#     dreal
# 0  0.5038
# 1  0.5028
# 2  0.5045
# 3  0.5057
# 4  0.5092

# %%
# !pip install psutil
# Out:
# The kernel failed to start due to the missing module 'psutil'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.

# %%
df = pd.read_csv("generatorv9.csv")
x = range(1, 181)
x1 = range(1, 120, 2)
plt.plot(x, dreal["dreal"], label="dreal")
plt.plot(x, dfake["dfake"], label="dfake")
plt.plot(x, np.zeros(180), linestyle="dashed", label="Desired Value")
leg = plt.legend(loc="lower right", bbox_to_anchor=(1.1, 1.1))

plt.title("cGAN Loss Over 60 Epochs")
plt.xlabel("Epoch #")
plt.ylabel("Loss (Wasserstein Distance)")
sns.set_theme()

plt.show('darkgrid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("generatorv9.csv")
#       2 x = range(1, 181)
#       3 x1 = range(1, 120, 2)
#
# NameError: name 'pd' is not defined

# %%
asdf = pd.read_csv("asdf.csv")

# %%
asdf.head()
# Out:
#    Policy Gradient Loss  Value Network Loss  Overall Loss
# 0               -0.0329                6.52          2.04
# 1               -0.0353                6.76          2.54
# 2               -0.0150               13.70          5.09
# 3               -0.0294                9.61          4.52

# %%
x = range(1, 5)
plt.plot(x, asdf["Policy Gradient Loss"], label="Policy Gradient Loss")
plt.plot(x, asdf['Value Network Loss'], label="Value Network Loss")
plt.plot(x, asdf["Overall Loss"], label="Overall Algorithm Loss")
plt.xlabel("Batch Index")
plt.ylabel("Loss (PPO)")
plt.title("PPO Loss Over Batches")
leg = plt.legend(loc="upper left")
plt.xlim([0.75, 4.25])
sns.set_theme()
plt.show('darkgrid')

# %%
test = pd.read_csv("test.csv")
test.head()
# Out:
#    Mean Reward  Standard Deviation
# 0        0.549               1.557
# 1        0.602               1.179
# 2        0.434               1.025
# 3        0.520               0.609
# 4        0.852               1.180

# %%
x = range(1, 11)
plt.plot(x, test["Mean Reward"], label="Mean Reward")
leg = plt.legend(loc="upper right")
plt.title("PPO Algorithm Test Losses")
plt.xlabel("Test Iteration")
plt.ylabel("Loss")
sns.set_theme()
plt.errorbar(x, test["Mean Reward"], test["Standard Deviation"], fmt='o')
plt.show('darkgrid')
